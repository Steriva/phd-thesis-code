# %% [markdown]
# # Generalised Empirical Interpolation Method: sensor placement
# This notebook takes the Snapshots and places the sensors using the Generalised Empirical Interpolation Method (GEIM).
#
# Let us create the mesh from the OpenFOAM nodes and cells

# %%
from pyforce.tools.write_read import ReadFromOF
from IPython.display import clear_output as clc

from matplotlib import cm, rcParams, pyplot as plt
import pickle

path_snaps = '../../../Data/MSFR/'
of = ReadFromOF(path_snaps+'ULOFF-reflector/', mode='pyvista')
domain = of.create_mesh()
# Out:
# WARNING:py.warnings:/Users/sriva/miniconda3/envs/ml/lib/python3.10/site-packages/pyforce/tools/write_read.py:262: UserWarning: The mesh contains more than one cell type.
#   warnings.warn('The mesh contains more than one cell type.')
# Hexahedron cells selected

# %% [markdown]
# Let us import the snapshots, variable names and time

# %%
import numpy as np
from dolfinx.fem import (Function, FunctionSpace)
from ufl import VectorElement
from pyforce.tools.functions_list import FunctionsList

_data = np.load('../ReflectorSensing/Results/variables.npz', allow_pickle=True)
var_names = _data['var_names']
is_vector = _data['is_vector']

fom_times = np.load('../ReflectorSensing/Results/times.npz')['fom_times']

measured_field = [0]
var_names = [var_names[i] for i in measured_field]
is_vector = [is_vector[i] for i in measured_field]
measured_field = 0

# Fun Spaces
fun_spaces = [
    FunctionSpace(domain, ("Lagrange", 1)),
]

snaps = {
    field: FunctionsList(fun_spaces[field_i])
    for field_i, field in enumerate(var_names)
}
for field_i, field in enumerate(var_names):

    _snap = np.load('../ReflectorSensing/Results/'+field+'.npz', allow_pickle=True)['field']

    for tt in range(len(fom_times)):
        snaps[field].append(_snap[:,tt])

# %% [markdown]
# Let us define the boundary-tags at which sensors will be placed

# %%
def is_out_core(node):
    return (((node[2] <= -1.13) or (node[2] >=  1.13) or (node[0] >= 2.05)) and
            ((node[1]<=0.02) or (node[1]>=-0.02)))

nodes = domain.geometry.x
out_core = np.array([is_out_core(node) for node in nodes])
out_core_idx = np.where(out_core)[0]
in_core_idx  = np.where(~out_core)[0]

import matplotlib.pyplot as plt
fig, axs = plt.subplots(figsize=(4, 4))
plt.plot(nodes[out_core_idx, 0], nodes[out_core_idx, 2], 'bo', markersize=2, label='OutCore')
plt.plot(nodes[in_core_idx, 0], nodes[in_core_idx, 2], 'ro', markersize=2, label='InCore')
plt.legend()

# %% [markdown]
# Let us split the snapshots into train, test and predict: predict include times $t>50$ seconds, train and test include times $t<50$ seconds, these are randomly selected.

# %%
from sklearn.model_selection import train_test_split

Nt = len(fom_times)

_indices = np.arange(0, Nt)
train_indices, test_indices = train_test_split(_indices, test_size=0.25, random_state=42)

train_indices = np.sort(train_indices)
test_indices = np.sort(test_indices)

train_snaps = dict()

for field_i, field in enumerate(var_names):
    train_snaps[field] = FunctionsList(fun_spaces[field_i])
    for ii in train_indices:
        train_snaps[field].append(snaps[field](ii) / snaps[field](0).max())

# %% [markdown]
# Let us define the available sensor positions. Three strategies are available:
# 1. No constraints (ID)
# 2. Constrained to the full boundary (BF)
# 3. Constrained to the true boundary (BP) - no symmetry

# %%
xm_list = {
    'ID': list(),
}

for tag in in_core_idx[::200]: 
    xm_list['ID'].append(nodes[tag])

sample_every = 200
s = 0.025

# %% [markdown]
# ## GEIM Training Phase
# Let us define the training phase of the GEIM.

# %%
from pyforce.offline.geim import GEIM

geim_offline = {
    strategy: GEIM(domain, fun_spaces[measured_field], var_names[measured_field], s=s)
    for strategy in xm_list.keys()
}

Mmax = 20

maxAbsErr = dict()
maxRelErr = dict()
betaCoeff = dict()

print('----------------------------------------------------------------------------')
for strategy in xm_list.keys():

    print(f'Running GEIM with {strategy} strategy')
    maxAbsErr[strategy], maxRelErr[strategy], betaCoeff[strategy] = geim_offline[strategy].offline(train_snaps[var_names[measured_field]], Mmax = Mmax,
                                                                                                    xm=xm_list[strategy], sampleEvery=sample_every,
                                                                                                    verbose=True)
    
    print(' ')
    print('----------------------------------------------------------------------------')
# Out:
# ----------------------------------------------------------------------------
# Running GEIM with ID strategy
# Generating sensors (coinstrained cells): 337.000 / 337.00 - 0.014 s/it
#   Iteration 020 | Abs Err: 8.19e-04 | Rel Err: 1.58e-03
# ----------------------------------------------------------------------------

# %% [markdown]
# Let us plot the decrease of the training error (absolute and relative)

# %%
fig, axs = plt.subplots(1,2,figsize=(12, 4))

for strategy in xm_list.keys():
    axs[0].plot(maxAbsErr[strategy], label=strategy)
    axs[1].plot(maxRelErr[strategy], label=strategy)

for ax in axs:
    ax.set_yscale('log')
    ax.set_xlabel('Number of Sensors $M$')
    ax.legend()
    ax.grid(which='major', linestyle='-')
    ax.grid(which='minor', linestyle='--')

axs[0].set_ylabel('Max Abs. Error')
axs[1].set_ylabel('Max Rel. Error')
# Out:
# Text(0, 0.5, 'Max Rel. Error')

# %% [markdown]
# Let us store the magic functions and sensors and the trained reduced coefficients.

# %%
import os
from pyforce.tools.write_read import StoreFunctionsList

path_offline = 'Results/GEIM_offline/'
os.makedirs(path_offline, exist_ok=True)

for strategy in xm_list.keys():
    StoreFunctionsList(domain, geim_offline[strategy].magic_fun, f'GEIM_{var_names[measured_field]}_{strategy}_mf',
                       filename = path_offline+f'GEIM_{var_names[measured_field]}_{strategy}_mf')
    StoreFunctionsList(domain, geim_offline[strategy].magic_sens, f'GEIM_{var_names[measured_field]}_{strategy}_ms',
                       filename = path_offline+f'GEIM_{var_names[measured_field]}_{strategy}_ms')
    
    np.savez_compressed(path_offline+f'GEIM_{var_names[measured_field]}_{strategy}_TrainBeta.npz',
                        betaCoeff[strategy])

# %% [markdown]
# Let us plot the magic functions

# %%
from utils import plot_contour

mf_to_plot = np.arange(0, 5, 1)
nrows = len(xm_list.keys())
ncols = len(mf_to_plot)

fig, axs = plt.subplots(nrows, ncols, figsize=(ncols*4, nrows*4))
axs = axs.reshape(nrows, ncols)

for row, strategy in enumerate(xm_list.keys()):
    for col in range(ncols):
        mf = geim_offline[strategy].magic_fun(mf_to_plot[col])
        cont = plot_contour(axs[row, col], 
                            np.stack([domain.geometry.x[:, 0], domain.geometry.x[:, 2]]).T, 
                            mf, levels=50)
        cbar = fig.colorbar(cont, ax=axs[row, col], fraction=0.046, pad=0.04)
    axs[row, 0].set_ylabel(list(xm_list.keys())[row])

for col in range(ncols):
    axs[0, col].set_title(f'Magic Function {mf_to_plot[col]+1}')

# %% [markdown]
# Let us plot the magic sensors

# %%
from matplotlib import patches

strategies_labels = ['Free']

sens_to_plot = 10

fig, axs = plt.subplots(1, len(xm_list.keys()), figsize=(len(xm_list.keys())*4, 4))
axs = [axs] if len(xm_list.keys()) == 1 else axs

for col, strategy in enumerate(xm_list.keys()):
    ms = np.zeros((train_snaps[var_names[measured_field]].fun_shape,))

    locs = list()

    for mm in range(sens_to_plot):
        ms += geim_offline[strategy].magic_sens(mm) / np.max(geim_offline[strategy].magic_sens(mm))
        locs.append(np.argmax(geim_offline[strategy].magic_sens(mm)))
    points = np.stack([domain.geometry.x[locs, 0], domain.geometry.x[locs, 2]]).T
    labels = [str(mm+1) for mm in range(sens_to_plot)]
    cont = plot_contour(axs[col], 
                        np.stack([domain.geometry.x[:, 0], domain.geometry.x[:, 2]]).T, 
                        ms, levels=20, cmap=cm.plasma_r)
    # axs[col].scatter(points[:, 0], points[:, 1], c='black', s=20, label='Sensors')
    axs[col].set_title(strategies_labels[col], fontsize=30)

    rec = patches.Rectangle((0, -2.26 / 2), 2.05, 2.26, linewidth=2, facecolor='none', edgecolor='red')
    axs[col].add_patch(rec)
    
    offset = 0.025
    for (x, y), label in zip(points, labels):
        axs[col].text(x + offset, y + offset, label, fontsize=18, color='black')
